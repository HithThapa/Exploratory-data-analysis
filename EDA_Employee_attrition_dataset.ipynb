# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv('C:/Users/HITH THAPA/Hith_py/Assignment/Final dataset Attrition (1).csv')

# %%
Data
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0      37       Yes  Travel_Rarely  Research & Development                 2
# 1      21        No  Travel_Rarely  Research & Development                15
# 2      45        No  Travel_Rarely  Research & Development                 6
# 3      23        No  Travel_Rarely                   Sales                 2
# 4      22        No  Travel_Rarely  Research & Development                15
# ...   ...       ...            ...                     ...               ...
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
# ...

# %%
Data.describe()
# Out:
#                Age  DistanceFromHome  JobInvolvement     JobLevel  \
# count  1470.000000       1470.000000     1470.000000  1470.000000
# mean     36.923810          9.192517        2.729932     2.063946
# std       9.135373          8.106864        0.711561     1.106940
# min      18.000000          1.000000        1.000000     1.000000
# 25%      30.000000          2.000000        2.000000     1.000000
# 50%      36.000000          7.000000        3.000000     2.000000
# 75%      43.000000         14.000000        3.000000     3.000000
# max      60.000000         29.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count      1470.000000    1470.000000         1470.000000        1470.000000
# mean          2.728571    6502.931293            2.693197          15.209524
# std           1.102846    4707.956783            2.498009           3.659938
# ...

# %%
Data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Higher_Education',
#        'Date_of_Hire', 'Date_of_termination', 'Status_of_leaving',
#        'Mode_of_work', 'Leaves', 'Absenteeism', 'Work_accident',
#        'Source_of_Hire', 'Job_mode'],
#       dtype='object')

# %%
Data.shape
# Out:
# (1470, 32)

# %% [markdown]
# ## Data Cleaning

# %%
# missing value
Data.isnull().sum().sort_values(ascending=False)
# Out:
# Date_of_termination        1470
# Age                           0
# Attrition                     0
# Source_of_Hire                0
# Work_accident                 0
# Absenteeism                   0
# Leaves                        0
# Mode_of_work                  0
# Status_of_leaving             0
# Date_of_Hire                  0
# Higher_Education              0
# YearsWithCurrManager          0
# YearsSinceLastPromotion       0
# YearsAtCompany                0
# TrainingTimesLastYear         0
# TotalWorkingYears             0
# StockOptionLevel              0
# PerformanceRating             0
# PercentSalaryHike             0
# OverTime                      0
# NumCompaniesWorked            0
# MonthlyIncome                 0
# MaritalStatus                 0
# JobSatisfaction               0
# JobRole                       0
# JobLevel                      0
# JobInvolvement                0
# Gender                        0
# DistanceFromHome              0
# ...

# %%
Data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# Removing missing value
# as all the value in Date_of_termination column is NAN so we can Drop whole of the column
# Deleting unnecessary column
Data_modified=Data.drop(['Date_of_termination'],axis=1)
Data_modified
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0      37       Yes  Travel_Rarely  Research & Development                 2
# 1      21        No  Travel_Rarely  Research & Development                15
# 2      45        No  Travel_Rarely  Research & Development                 6
# 3      23        No  Travel_Rarely                   Sales                 2
# 4      22        No  Travel_Rarely  Research & Development                15
# ...   ...       ...            ...                     ...               ...
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
# ...

# %%
Data_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   object
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   object
# ...

# %%
#Finding Outliers
Data_modified.describe()
# Out:
#                Age  DistanceFromHome  JobInvolvement     JobLevel  \
# count  1470.000000       1470.000000     1470.000000  1470.000000
# mean     36.923810          9.192517        2.729932     2.063946
# std       9.135373          8.106864        0.711561     1.106940
# min      18.000000          1.000000        1.000000     1.000000
# 25%      30.000000          2.000000        2.000000     1.000000
# 50%      36.000000          7.000000        3.000000     2.000000
# 75%      43.000000         14.000000        3.000000     3.000000
# max      60.000000         29.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count      1470.000000    1470.000000         1470.000000        1470.000000
# mean          2.728571    6502.931293            2.693197          15.209524
# std           1.102846    4707.956783            2.498009           3.659938
# ...

# %%
Data_modified['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
plt.boxplot(Data_modified['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2487b110550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2487b108550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2487ae91c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2487b1598d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2487b15a0d0>],
#  'means': []}

# %% [markdown]
# **With the help of above boxplot we can see that there are outliers in monthly income column but those outliers are not an outliers because we know one can get monthly salary more than 20,000/-**

# %%
compare=['MonthlyIncome']
Set=Data_modified.groupby('Gender')[compare].mean()
indx=np.arange(len(compare))
Sal_label=np.arange(1000,10000,1000)
male=list(Set.T['Male'])
female=list(Set.T['Female'])
bar_width=0.3
fig, ax=plt.subplots()
bar_male=ax.bar(indx - bar_width/2,male,bar_width,label='Male')
bar_Female=ax.bar(indx + bar_width/2,female,bar_width,label='Female')
ax.set_xticks(indx)
ax.set_xticklabels(compare)
ax.set_yticks(Sal_label)
ax.set_yticklabels(Sal_label)
ax.legend()
# for i in indx:
#     ax.annotate('{0:.0f}'.format(bar_male[i].get_height()),
#                 xy=(bar_male[i].get_x()/100000+ bar_male[i].get_width() / 2, bar_male[i].get_height()),
#                 textcoords='offset points',
#                 ha='center',
#                 va='bottom'
#                )
# for i in indx:
#     ax.annotate('{0:.0f}'.format(bar_Female[i].get_height()),
#                 xy=(bar_Female[i].get_x() + bar_Female[i].get_width() / 2, bar_Female[i].get_height()),
#                 textcoords='offset points',
#                 ha='center',
#                 va='bottom'
#                )
plt.show()

# %%
List=['JobInvolvement','JobLevel','Leaves']
Show=Data_modified.groupby('Gender')[List].mean()
idx=np.arange(len(List))
Sal_lbl=np.arange(0,6,2)
print(Show)
ymale=list(Show.T['Male'])
xfemale=list(Show.T['Female'])
bar_wdth=0.35
fig, ax=plt.subplots()
bar_mae=ax.bar(idx - bar_wdth/2,ymale,bar_wdth,label='Male')
bar_Femae=ax.bar(idx + bar_wdth/2,xfemale,bar_wdth,label='Female')
ax.set_xticks(idx)
ax.set_xticklabels(List)
ax.set_yticks(Sal_lbl)
ax.set_yticklabels(Sal_lbl)
ax.legend()
plt.show()
# Out:
#         JobInvolvement  JobLevel    Leaves
# Gender
# Female        2.714286  2.117347  2.620748
# Male          2.740363  2.028345  2.534014

# %%
Data_modified.groupby('Gender')['MonthlyIncome'].plot()
plt.legend()

# %%
Data_modified.groupby('Gender')['JobLevel'].plot()
plt.legend()

# %%
Data_modified.groupby('JobLevel')['Leaves'].plot()
plt.legend()

# %%
# upper=Data_modified['MonthlyIncome'].quantile(0.95)
# lower=Data_modified['MonthlyIncome'].quantile(0.05)
# lower,upper

# %% [markdown]
# ## Univariate Analysis

# %%
#Histogram
plt.subplot(1,2,2)
plt.hist(Data_modified['Age'])
plt.xlabel('Age')
plt.subplot(1,2,1)
plt.hist(Data_modified['JobLevel']);
plt.xlabel('JobLevel');

# %% [markdown]
# **Here in above two graph we can see that first graph told us that most of the employee are at JobLevel of 1 and 2 and in second graph we can see that most of the employees are in between age group of 30-50 yrs**

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
Data_modified['JobRole'].value_counts().plot.pie()
plt.subplot(1,2,2)
Data_modified['Higher_Education'].value_counts().plot.pie()
# plt.xlabel('JOB-ROLE')
# plt.subplot(2,1,2)
# label=Data_modified['JobRole'].unique()
# label
# plt.pie(Data_modified['JobRole'].value_counts(), labels=label)
# Out:
# <AxesSubplot: ylabel='Higher_Education'>

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.hist(Data_modified['Department'])
plt.xlabel('Department');
plt.xticks(rotation=90)
plt.subplot(1,3,2)
plt.hist(Data_modified['JobRole'])
plt.xlabel('JobRole')
plt.xticks(rotation=90)
plt.subplot(1,3,3)
plt.hist(Data_modified['Gender'])
plt.xlabel('Gender')
plt.xticks(rotation=90)
# Out:
# ([0, 1], [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %% [markdown]
# **Here we can see that most of the employees are from Research and Development Deparement and very few are from Human Resources and with another graph we can see that it is a male dominating company**

# %% [markdown]
# # Bivariate Analysis

# %%
#Scatter Plot
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.scatter(Data_modified['JobLevel'],Data_modified['MonthlyIncome'])
plt.xlabel('JobLevel')
plt.ylabel('MonthlyIncome')
plt.subplot(1,2,2)
plt.scatter(Data_modified['Age'],Data_modified['MonthlyIncome'])
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
#Scatter Plot
plt.scatter(Data_modified['Department'],Data_modified['MonthlyIncome'])
plt.xlabel('Department')
plt.ylabel('MonthlyIncome')
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %% [markdown]
# **In above graph we can see that the data are following the trend so there is no outliers in it**

# %%
#barPlot
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.bar(Data_modified['JobRole'],Data_modified['MonthlyIncome'])
plt.title('JobRole vs MonthlyIncome Graph')
plt.xlabel('JobRole')
plt.ylabel('MonthlyIncome')
plt.xticks(rotation=90)
plt.subplot(1,2,2)
plt.bar(Data_modified['JobLevel'],Data_modified['TotalWorkingYears'])
plt.title('JobLevel vs Working Years Graph')
plt.xlabel('JobLevel')
plt.ylabel('Working Years')
# Out:
# Text(0, 0.5, 'Working Years')

# %%
#boxplot
sns.boxplot(x='JobLevel',y='TotalWorkingYears',data=Data_modified)
# Out:
# <AxesSubplot: xlabel='JobLevel', ylabel='TotalWorkingYears'>

# %%
#Pair Plot
sns.pairplot(data=Data_modified,vars=['Age','MonthlyIncome','JobLevel'])

# %%
dd=Data_modified[['Leaves','Gender']]
dd
# Out:
#       Leaves  Gender
# 0          4    Male
# 1          5    Male
# 2          1    Male
# 3          1    Male
# 4          5  Female
# ...      ...     ...
# 1465       3    Male
# 1466       1    Male
# 1467       2    Male
# 1468       2    Male
# 1469       4  Female
#
# [1470 rows x 2 columns]

# %%
mm=dd[dd['Gender']=='Male']
ff=dd[dd['Gender']=='Female']
xy=mm['Leaves'].sum()
xx=ff['Leaves'].sum()
xy,xx
# dd['Gender'].value_counts()
# Out:
# (2235, 1541)

# %%
sns.boxplot(x='Gender',y='Leaves',data=Data_modified)
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
# Heatmap
data=Data_modified[['Age','JobLevel','MonthlyIncome']].corr()
sns.heatmap(data=data,annot=True,cmap='Reds')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
#Multivariate Analysis
result=pd.pivot_table(data=Data_modified ,index='Department',columns='Higher_Education',values='JobLevel')
print(result)
sns.heatmap(data=result,annot=True,cmap='Reds')
# Out:
# Higher_Education            12th  Graduation       PHD  Post-Graduation
# Department
# Human Resources         2.000000    2.300000  1.642857         2.071429
# Research & Development  2.016878    1.934363  1.986239         1.975709
# Sales                   2.198113    2.443182  2.111111         2.317460
# <AxesSubplot: xlabel='Higher_Education', ylabel='Department'>
